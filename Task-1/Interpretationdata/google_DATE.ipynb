# %% [markdown]
# **Import Libraries**

# %%
import pandas as pd
import numpy as numpy
import seaborn as sns
import matplotlib.pyplot as plt 
import math

# %% [markdown]
# **Data Preprocessing**

# %%
data=pd.read_csv('DIGITAL_MARKETING_APP_DATE_GOOGLE.csv')

# %%
data.head()
# Out:
#          DATE  C_COMPILER  C_TUTORIAL  CSHARP_COMPILER  CSHARP_TUTORIAL  \
# 0  2021-05-28          20           1                2                0
# 1  2021-05-29          16          40                0                0
# 2  2021-05-30           6          25                0                0
# 3  2021-05-31           4          20                0                0
# 4  2021-06-01           8          10                1                0
#
#    CPLUSPLUS_COMPILER  CPLUSPLUS_TUTORIAL  CALCULATORPLUS  CALENDARPLUS  \
# 0                   2                   0               1             3
# 1                   0                   5               0            28
# 2                   0                   1               0             2
# 3                   0                  29               2             2
# 4                   6                   0              12             1
#
#    COMPILERPLUS  ...  PYTHON_TUTORIAL  RUBY_COMPILER  RUBY_TUTORIAL  \
# ...

# %%
data.describe()
# Out:
#        C_COMPILER  C_TUTORIAL  CSHARP_COMPILER  CSHARP_TUTORIAL  \
# count  320.000000  320.000000       320.000000       320.000000
# mean     5.618750    4.471875         4.640625         3.465625
# std     16.128548    9.185949        12.423518        11.887617
# min      0.000000    0.000000         0.000000         0.000000
# 25%      0.000000    0.000000         0.000000         0.000000
# 50%      2.000000    1.000000         0.000000         0.000000
# 75%      5.000000    5.000000         2.000000         1.000000
# max    245.000000   63.000000        88.000000       104.000000
#
#        CPLUSPLUS_COMPILER  CPLUSPLUS_TUTORIAL  CALCULATORPLUS  CALENDARPLUS  \
# count          320.000000           320.00000      320.000000    320.000000
# mean             3.634375             6.57500        4.203125      3.440625
# std             10.880978            21.77645       21.313880     10.441488
# min              0.000000             0.00000        0.000000      0.000000
# ...

# %%
data.shape
# Out:
# (320, 37)

# %% [markdown]
# Here we are going to use thsi csv to validate our interpretations

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320 entries, 0 to 319
# Data columns (total 37 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DATE                 320 non-null    object
#  1   C_COMPILER           320 non-null    int64
#  2   C_TUTORIAL           320 non-null    int64
#  3   CSHARP_COMPILER      320 non-null    int64
#  4   CSHARP_TUTORIAL      320 non-null    int64
#  5   CPLUSPLUS_COMPILER   320 non-null    int64
#  6   CPLUSPLUS_TUTORIAL   320 non-null    int64
#  7   CALCULATORPLUS       320 non-null    int64
#  8   CALENDARPLUS         320 non-null    int64
#  9   COMPILERPLUS         320 non-null    int64
#  10  CSS_TUTORIAL         320 non-null    int64
#  11  DART_COMPILER        320 non-null    int64
#  12  DART_TUTORIAL        320 non-null    int64
#  13  GO_COMPILER          320 non-null    int64
#  14  GO_TUTORIAL          320 non-null    int64
# ...

# %%
data.hist(bins=50,figsize=(15,15))
plt.show()

# %%
data.corr()
# Out:
#                      C_COMPILER  C_TUTORIAL  CSHARP_COMPILER  CSHARP_TUTORIAL  \
# C_COMPILER             1.000000    0.287559         0.044919        -0.041794
# C_TUTORIAL             0.287559    1.000000         0.100461        -0.023836
# CSHARP_COMPILER        0.044919    0.100461         1.000000         0.175084
# CSHARP_TUTORIAL       -0.041794   -0.023836         0.175084         1.000000
# CPLUSPLUS_COMPILER    -0.050687   -0.046818         0.053938        -0.021315
# CPLUSPLUS_TUTORIAL    -0.062601   -0.071113        -0.010103        -0.036240
# CALCULATORPLUS         0.009418   -0.021482         0.067402        -0.010359
# CALENDARPLUS          -0.053019   -0.008613        -0.029635         0.073552
# COMPILERPLUS           0.195520    0.471439         0.031116        -0.014745
# CSS_TUTORIAL           0.006590   -0.008579         0.377383         0.322855
# DART_COMPILER         -0.019111   -0.045898        -0.016438        -0.007156
# ...

# %%
sns.pairplot(data)

# %%
data.isnull().sum()
# Out:
# DATE                   0
# C_COMPILER             0
# C_TUTORIAL             0
# CSHARP_COMPILER        0
# CSHARP_TUTORIAL        0
# CPLUSPLUS_COMPILER     0
# CPLUSPLUS_TUTORIAL     0
# CALCULATORPLUS         0
# CALENDARPLUS           0
# COMPILERPLUS           0
# CSS_TUTORIAL           0
# DART_COMPILER          0
# DART_TUTORIAL          0
# GO_COMPILER            0
# GO_TUTORIAL            0
# HTML_TUTORIAL          0
# JAVA_COMPILER          0
# JAVA_TUTORIAL          0
# JAVASCRIPT_COMPILER    0
# JAVASCRIPT_TUTORIAL    0
# KOTLIN_COMPILER        0
# KOTLIN_TUTORIAL        0
# MOTIVATIONPLUS         0
# NOTESPLUS              0
# PHP_COMPILER           0
# PHP_TUTORIAL           0
# PYTHON_COMPILER        0
# PYTHON_TUTORIAL        0
# RUBY_COMPILER          0
# RUBY_TUTORIAL          0
# SUCCESS_STORIES        0
# SWIFT_COMPILER         0
# SWIFT_TUTORIAL         0
# TASKSPLUS              0
# TIMEPLUS               0
# TRAVEL_DIARIES         0
# XML_TUTORIAL           0
# ...

# %%
plt.figure(figsize=(30,10))
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()
trans=scaler.fit_transform(data.drop(columns=['DATE']))

# %%
trans=pd.DataFrame(trans,columns=data.columns[:-1])
trans
# Out:
#          DATE  C_COMPILER  C_TUTORIAL  CSHARP_COMPILER  CSHARP_TUTORIAL  \
# 0    0.081633    0.015873    0.022727              0.0         0.024096
# 1    0.065306    0.634921    0.000000              0.0         0.000000
# 2    0.024490    0.396825    0.000000              0.0         0.000000
# 3    0.016327    0.317460    0.000000              0.0         0.000000
# 4    0.032653    0.158730    0.011364              0.0         0.072289
# ..        ...         ...         ...              ...              ...
# 315  0.000000    0.000000    0.000000              0.0         0.000000
# 316  0.000000    0.000000    0.000000              0.0         0.000000
# 317  0.000000    0.000000    0.000000              0.0         0.000000
# 318  0.000000    0.000000    0.000000              0.0         0.000000
# 319  0.000000    0.000000    0.000000              0.0         0.000000
#
#      CPLUSPLUS_COMPILER  CPLUSPLUS_TUTORIAL  CALCULATORPLUS  CALENDARPLUS  \
# ...

# %% [markdown]
# Our interpretations have been validated and we can see that the pairplots match to the data. The trans data also provides us similar results. The heatplot focuses on each app on a larger scale.
